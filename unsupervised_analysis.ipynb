# %% [markdown]
# ## Unsupervised learning

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %% [markdown]
# ## Get Data

# %%
from juypterWorkflowna.data import get_fremont_data
data=get_fremont_data()
pivoted=data.pivot_table('Total',index=data.index.time,columns=data.index.date)
pivoted.plot(legend=False,alpha=0.01);

# %%
X=pivoted.T.fillna(0).values

# %% [markdown]
# ## PCA

# %%
X2=PCA(2).fit_transform(X)

# %%
plt.scatter(X2[:,0],X2[:,1]);

# %% [markdown]
# ## GMM

# %%
gmm=GaussianMixture(2)
gmm.fit(X)
labels=gmm.predict(X)

# %%
plt.scatter(X2[:,0],X2[:,1],c=labels,cmap='rainbow')
plt.colorbar();

# %%
fig,ax=plt.subplots(1,2,figsize=(14,6))
pivoted.T[labels==0].T.plot(alpha=0.01,legend=False,ax=ax[0]);
pivoted.T[labels==1].T.plot(alpha=0.01,legend=False,ax=ax[1]);
ax[0].set_title("blue day");

# %% [markdown]
# ## Comparing with day of week

# %%
dayofweek=pd.DatetimeIndex(pivoted.columns).dayofweek

# %%
plt.scatter(X2[:,0],X2[:,1],c=dayofweek,cmap='rainbow')
plt.colorbar();

# %% [markdown]
# ## Analyzing outliers

# %%
dates=pd.DatetimeIndex(pivoted.columns)

# %%
dates[(labels==1) & (dayofweek<5)]
# Out:
# DatetimeIndex(['2012-11-22', '2012-11-23', '2012-12-24', '2012-12-25',
#                '2013-01-01', '2013-05-27', '2013-07-04', '2013-07-05',
#                '2013-09-02', '2013-11-28', '2013-11-29', '2013-12-20',
#                '2013-12-25', '2014-01-01', '2014-04-23', '2014-05-26',
#                '2014-07-04', '2014-09-01', '2014-11-27', '2014-11-28',
#                '2014-12-24', '2014-12-25', '2014-12-26', '2015-01-01',
#                '2015-05-25', '2015-07-03', '2015-09-07', '2015-11-26',
#                '2015-11-27', '2015-12-24', '2015-12-25', '2016-01-01',
#                '2016-05-30', '2016-07-04', '2016-09-05', '2016-11-24',
#                '2016-11-25', '2016-12-26', '2017-01-02', '2017-02-06',
#                '2017-05-29', '2017-07-04', '2017-09-04', '2017-11-23',
#                '2017-11-24', '2017-12-25', '2017-12-26', '2018-01-01',
#                '2018-05-28', '2018-07-04', '2018-09-03', '2018-11-22',
# ...
